# %% [markdown]
# ## Historical Max Temperature from Tomorrow.io API
#
# We retrieve the max temperature (i.e., `temperatureMax`) for Delhi, India on [H3 resolution 7](https://h3geo.org) from the [Historical](https://docs.tomorrow.io/reference/historical) data layer of the [Tomorrow.io API](https://docs.tomorrow.io/reference/api-introduction).

# %%
# %reload_ext autoreload
# %autoreload 2

import asyncio
import json
import os
from typing import Optional

import geopandas
import h3
import pandas as pd
import shapely
from aiohttp import ClientSession
from shapely.geometry import Polygon

from utilities import weatherFunctions
# Out:
# INFO:utilities:Initializing custom packages

# %% [markdown]
# The following are auxiliary function(s). Ideally, these will be packaged in an opportune moment.

# %%
def get_h3_tessellation(
    gdf: geopandas.GeoDataFrame, name="shapeName", resolution=10
) -> geopandas.GeoDataFrame:
    mapper = dict()
    tiles = set()

    # TODO: vectorize, if possible
    for idx, row in gdf.iterrows():
        geometry = row["geometry"] 
        match geometry.geom_type:
            case "Polygon":
                hex_ids = h3.polyfill(
                    shapely.geometry.mapping(geometry),
                    resolution,
                    geo_json_conformant=True,
                )

                tiles = tiles.union(set(hex_ids))
                mapper.update([(hex_id, row[name]) for hex_id in hex_ids])

            case "MultiPolygon":
                for x in geometry.geoms:
                    hex_ids = h3.polyfill(
                        shapely.geometry.mapping(x),
                        resolution,
                        geo_json_conformant=True,
                    )

                    tiles = tiles.union(set(hex_ids))
                    mapper.update([(hex_id, row[name]) for hex_id in hex_ids])
            case _:
                raise (Exception)

    tessellation = geopandas.GeoDataFrame(
        data=tiles,
        geometry=[Polygon(h3.h3_to_geo_boundary(idx, True)) for idx in tiles],
        columns=["hex_id"],
        crs="EPSG:4326",
    )

    return tessellation

# %%
# create the Tomorrow.io API token at https://app.tomorrow.io/development/keys
TOMORROW_API_KEY = <KEY>

# %% [markdown]
# ## Area of Interest: Chennai

# %%
# PHILIPPINES  = geopandas.read_file('../../data/shapefiles/philippines/phl_adminboundaries_candidate_exclude_adm3/phl_admbnda_adm2_psa_namria_20200529.shp')
# MANILA = PHILIPPINES[PHILIPPINES['ADM2_EN'].isin(['NCR, City of Manila, First District', 'NCR, Second District', 'NCR, Third District', 'NCR, Fourth District'])]
#PHILIPPINES_ADM3 = geopandas.read_file('../../data/shapefiles/philippines/phl_adminboundaries_candidate_adm3/phl_admbnda_adm3_psa_namria_20200529.shp')
#Manila_Neighbors = PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin(['Rodriguez', 'San Mateo', 'City of San Pedro', 'Obando'])]

#PHILIPPINES_ADM3 = geopandas.read_file('../../data/shapefiles/philippines/phl_adminboundaries_candidate_adm3/phl_admbnda_adm3_psa_namria_20200529.shp')
ZAMBOANGA = PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin(['Zamboanga City'])]

# SAN_MATEO=PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin([])]
# SAN_PEDRO=PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin([])]
# OBANDO=PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin([])]
#MANILA2 = PHILIPPINES[PHILIPPINES['ADM2_EN'].isin(['NCR, Second District'])]
#MANILA3 = PHILIPPINES[PHILIPPINES['ADM2_EN'].isin(['NCR, Third District'])]
#MANILA4 = PHILIPPINES[PHILIPPINES['ADM2_EN'].isin(['NCR, Fourth District'])]


# DAVAO = PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin(['Davao City'])]
# ZAMBOANGA = PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin(['Zamboanga City'])]
# CEBU = PHILIPPINES_ADM3[PHILIPPINES_ADM3['ADM3_EN'].isin(['Cebu City'])]

# %% [markdown]
# ## Tessellation in H3
#
# In this step, we generate a tessellation layer for the **area of interest** using [H3 resolution 7](https://h3geo.org).

# %%
TESSELLATION = get_h3_tessellation(ZAMBOANGA, name='ADM3_EN', resolution=7)

# %%
TESSELLATION.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22e1327b02e913c186f57b063ffba80b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22e1327b02e913c186f57b063ffba80b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22e1327b02e913c186f57b063ffba80b = L.map(
#                 &quot;map_22e1327b02e913c186f57b063ffba80b&quot;,
#                 {
#                     center: [7.183686054880793, 122.1424836159068],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_22e1327b02e913c186f57b063ffba80b);
#
#
#
#
#
#             var tile_layer_00685c9c354b46cc58f3fedb8f3a618f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22e1327b02e913c186f57b063ffba80b);
#
#
#             map_22e1327b02e913c186f57b063ffba80b.fitBounds(
#                 [[6.852426075447768, 121.89035331770215], [7.514946034313818, 122.39461391411143]],
#                 {}
#             );
#
#
#         function geo_json_477bdab03e3d4113d4830924c99f0563_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_477bdab03e3d4113d4830924c99f0563_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_477bdab03e3d4113d4830924c99f0563_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_477bdab03e3d4113d4830924c99f0563_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_477bdab03e3d4113d4830924c99f0563_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_477bdab03e3d4113d4830924c99f0563.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_477bdab03e3d4113d4830924c99f0563_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_477bdab03e3d4113d4830924c99f0563 = L.geoJson(null, {
#                 onEachFeature: geo_json_477bdab03e3d4113d4830924c99f0563_onEachFeature,
#
#                 style: geo_json_477bdab03e3d4113d4830924c99f0563_styler,
#                 pointToLayer: geo_json_477bdab03e3d4113d4830924c99f0563_pointToLayer
#         });
#
#         function geo_json_477bdab03e3d4113d4830924c99f0563_add (data) {
#             geo_json_477bdab03e3d4113d4830924c99f0563
#                 .addData(data)
#                 .addTo(map_22e1327b02e913c186f57b063ffba80b);
#         }
#             geo_json_477bdab03e3d4113d4830924c99f0563_add({&quot;bbox&quot;: [121.89035331770215, 6.852426075447768, 122.39461391411143, 7.514946034313818], &quot;features&quot;: [{&quot;bbox&quot;: [122.20072780496588, 7.41376508149993, 122.22524396052866, 7.439991557058898], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[122.20072780496588, 7.431159346600085], [122.20311688790859, 7.418046799220287], [122.21537434750108, 7.41376508149993], [122.22524396052866, 7.4225970171945], [122.22285476596298, 7.435710945315155], [122.21059606981355, 7.439991557058898], [122.20072780496588, 7.431159346600085]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properti

# %%
TESSELLATION['centre'] = TESSELLATION['geometry'].apply(lambda x: x.centroid)

# %%
TESSELLATION["geojson"] = TESSELLATION["geometry"].apply(
    lambda x: json.dumps(shapely.geometry.mapping(x))
)

TESSELLATION["centre_geojson"] = TESSELLATION["centre"].apply(
    lambda x: json.dumps(shapely.geometry.mapping(x))
)

# %% [markdown]
# ## Retrieve `Historical` from Tomorrow.io API
#
# > Tomorrow.io's Historical Weather API allows you to query weather conditions (limited to historical data layers ]) by specifying the location (GeoJSON of a Point, LineString or Polygon), fields ("temperature", "windSpeed", ...), timesteps ("1h", "1d") and the startTime and endTime, such that the response include a historical timeline.
#
#     Polygon and Polyline limits:
#
#     Polygon - 10,000 square km and no more than 70km per segment.
#     Polyline - 2,000 km long.
#     Max number of vertices - 550.
#     Timerange is limited to up to 30 days per API call.
#
#     If the location is a Polygon or a Polyline, you can specify whether you want the min/max/avg values throughout that coverage area by adding them as a suffix to any of the available fields (temperatureMax, temperatureMaxTime) and if not specified the response will default to Max.
#
#     The historical archive is based on a reanalysis model that blends past short-range weather forecasts with observations through advanced data assimilation techniques. The historical archive data deviates from the recent historical data -7 days since it is based on a different observation data assimilation system that incorporates a larger set of final observational records.
#     Please note that our reanalysis model takes between 7 to 90 days to calculate the data fields. Please see the historical data field Availability.
#
#     See also: https://docs.tomorrow.io/reference/historical-overview

# %%
class TomorrowAPIClient:
    """An Asynchronous API client for Tomorrow.io API"

    Parameters
    ----------
    token : str
        Tomorrow.io API token

    Notes
    -----
    For more information, please see https://docs.tomorrow.io
    """

    BASE_URL = "https://api.tomorrow.io/v4"

    def __init__(
        self, session: Optional[ClientSession] = None, token: Optional[str] = None
    ):
        self.session = session or ClientSession()
        self.semaphore = asyncio.BoundedSemaphore(4)
        self.token = token or os.getenv("TOMORROW_TOKEN")

    async def __aenter__(self):
        return self

    async def __aexit__(self, *args):
        await self.close()

    async def close(self):
        await self.session.close()

    async def post(self, url, json, params={}, headers={}):
        params["apikey"] = self.token
        async with self.semaphore, self.session.post(
            url, json=json, params=params, headers=headers
        ) as response:
            return await response.json()

# %% [markdown]
# ### Creating `intervals`
#
# Let's start in 2021, from January 1st to December 31th. The Tomorrow.io API limits the date range to 30 days. Thus, we create 13 periods of 28 days and add 1 day to the last period.

# %%
date_range = pd.date_range("2023-04-01 12:00:00", "2023-04-30 12:00:00", periods=30)
intervals = list(zip(date_range, date_range[1:]))

# %%
intervals
# Out:
# [(Timestamp('2023-04-01 12:00:00'), Timestamp('2023-04-02 12:00:00')),
#  (Timestamp('2023-04-02 12:00:00'), Timestamp('2023-04-03 12:00:00')),
#  (Timestamp('2023-04-03 12:00:00'), Timestamp('2023-04-04 12:00:00')),
#  (Timestamp('2023-04-04 12:00:00'), Timestamp('2023-04-05 12:00:00')),
#  (Timestamp('2023-04-05 12:00:00'), Timestamp('2023-04-06 12:00:00')),
#  (Timestamp('2023-04-06 12:00:00'), Timestamp('2023-04-07 12:00:00')),
#  (Timestamp('2023-04-07 12:00:00'), Timestamp('2023-04-08 12:00:00')),
#  (Timestamp('2023-04-08 12:00:00'), Timestamp('2023-04-09 12:00:00')),
#  (Timestamp('2023-04-09 12:00:00'), Timestamp('2023-04-10 12:00:00')),
#  (Timestamp('2023-04-10 12:00:00'), Timestamp('2023-04-11 12:00:00')),
#  (Timestamp('2023-04-11 12:00:00'), Timestamp('2023-04-12 12:00:00')),
#  (Timestamp('2023-04-12 12:00:00'), Timestamp('2023-04-13 12:00:00')),
#  (Timestamp('2023-04-13 12:00:00'), Timestamp('2023-04-14 12:00:00')),
#  (Timestamp('2023-04-14 12:00:00'), Timestamp('2023-04-15 12:00:00')),
#  (Timestamp('2023-04-15 12:00:00'), Timestamp('2023-04-16 12:00:00')),
#  (Timestamp('2023-04-16 12:00:00'), Timestamp('2023-04-17 12:00:00')),
#  (Timestamp('2023-04-17 12:00:00'), Timestamp('2023-04-18 12:00:00')),
#  (Timestamp('2023-04-18 12:00:00'), Timestamp('2023-04-19 12:00:00')),
#  (Timestamp('2023-04-19 12:00:00'), Timestamp('2023-04-20 12:00:00')),
#  (Timestamp('2023-04-20 12:00:00'), Timestamp('2023-04-21 12:00:00')),
#  (Timestamp('2023-04-21 12:00:00'), Timestamp('2023-04-22 12:00:00')),
#  (Timestamp('2023-04-22 12:00:00'), Timestamp('2023-04-23 12:00:00')),
#  (Timestamp('2023-04-23 12:00:00'), Timestamp('2023-04-24 12:00:00')),
#  (Timestamp('2023-04-24 12:00:00'), Timestamp('2023-04-25 12:00:00')),
#  (Timestamp('2023-04-25 12:00:00'), Timestamp('2023-04-26 12:00:00')),
#  (Timestamp('2023-04-26 12:00:00'), Timestamp('2023-04-27 12:00:00')),
#  (Timestamp('2023-04-27 12:00:00'), Timestamp('2023-04-28 12:00:00')),
#  (Timestamp('2023-04-28 12:00:00'), Timestamp('2023-04-29 12:00:00')),
#  (Timestamp('2023-04-29 12:00:00'), Timestamp('2023-04-30 12:00:00'))]

# %% [markdown]
# Fix by adding last day,

# %% [markdown]
# ### Create `payloads`

# %%
payloads = [
    {
        "location": location,
        "fields": ["temperatureMin", 'humidityMin'],
        "timesteps": ["1d"],
        "startTime": startTime.isoformat(),
        "endTime": endTime.isoformat(),
        "units": "metric",
    }
    for location in TESSELLATION["geojson"]
    for (startTime, endTime) in intervals
]

# %%
len(payloads)
# Out:
# 7975

# %% [markdown]
# Just checking the cardinality,

# %%
len(payloads) == len(TESSELLATION) * len(intervals)
# Out:
# True

# %%
payloads
# Out:
# [{'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-01T12:00:00',
#   'endTime': '2023-04-02T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-02T12:00:00',
#   'endTime': '2023-04-03T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-03T12:00:00',
#   'endTime': '2023-04-04T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-04T12:00:00',
#   'endTime': '2023-04-05T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-05T12:00:00',
#   'endTime': '2023-04-06T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-06T12:00:00',
#   'endTime': '2023-04-07T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-07T12:00:00',
#   'endTime': '2023-04-08T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-08T12:00:00',
#   'endTime': '2023-04-09T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-09T12:00:00',
#   'endTime': '2023-04-10T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-10T12:00:00',
#   'endTime': '2023-04-11T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-11T12:00:00',
#   'endTime': '2023-04-12T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-12T12:00:00',
#   'endTime': '2023-04-13T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-13T12:00:00',
#   'endTime': '2023-04-14T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-14T12:00:00',
#   'endTime': '2023-04-15T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-15T12:00:00',
#   'endTime': '2023-04-16T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-16T12:00:00',
#   'endTime': '2023-04-17T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-17T12:00:00',
#   'endTime': '2023-04-18T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-18T12:00:00',
#   'endTime': '2023-04-19T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-19T12:00:00',
#   'endTime': '2023-04-20T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-20T12:00:00',
#   'endTime': '2023-04-21T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-21T12:00:00',
#   'endTime': '2023-04-22T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-22T12:00:00',
#   'endTime': '2023-04-23T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-23T12:00:00',
#   'endTime': '2023-04-24T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-24T12:00:00',
#   'endTime': '2023-04-25T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-25T12:00:00',
#   'endTime': '2023-04-26T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-26T12:00:00',
#   'endTime': '2023-04-27T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-27T12:00:00',
#   'endTime': '2023-04-28T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-28T12:00:00',
#   'endTime': '2023-04-29T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.02348215151316, 14.436437723433103], [121.02588986118877, 14.42383751951722], [121.03813526771623, 14.420163571446368], [121.04797426844507, 14.429091146114983], [121.04556640603099, 14.441692561869724], [121.03331969545023, 14.445365191213625], [121.02348215151316, 14.436437723433103]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-29T12:00:00',
#   'endTime': '2023-04-30T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-01T12:00:00',
#   'endTime': '2023-04-02T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-02T12:00:00',
#   'endTime': '2023-04-03T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-03T12:00:00',
#   'endTime': '2023-04-04T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-04T12:00:00',
#   'endTime': '2023-04-05T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-05T12:00:00',
#   'endTime': '2023-04-06T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-06T12:00:00',
#   'endTime': '2023-04-07T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-07T12:00:00',
#   'endTime': '2023-04-08T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-08T12:00:00',
#   'endTime': '2023-04-09T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-09T12:00:00',
#   'endTime': '2023-04-10T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-10T12:00:00',
#   'endTime': '2023-04-11T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-11T12:00:00',
#   'endTime': '2023-04-12T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-12T12:00:00',
#   'endTime': '2023-04-13T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-13T12:00:00',
#   'endTime': '2023-04-14T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-14T12:00:00',
#   'endTime': '2023-04-15T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-15T12:00:00',
#   'endTime': '2023-04-16T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-16T12:00:00',
#   'endTime': '2023-04-17T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-17T12:00:00',
#   'endTime': '2023-04-18T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-18T12:00:00',
#   'endTime': '2023-04-19T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-19T12:00:00',
#   'endTime': '2023-04-20T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-20T12:00:00',
#   'endTime': '2023-04-21T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-21T12:00:00',
#   'endTime': '2023-04-22T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-22T12:00:00',
#   'endTime': '2023-04-23T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-23T12:00:00',
#   'endTime': '2023-04-24T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-24T12:00:00',
#   'endTime': '2023-04-25T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-25T12:00:00',
#   'endTime': '2023-04-26T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-26T12:00:00',
#   'endTime': '2023-04-27T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-27T12:00:00',
#   'endTime': '2023-04-28T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-28T12:00:00',
#   'endTime': '2023-04-29T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.06085075111193, 14.603344361547915], [121.06325929341511, 14.59075606623248], [121.07551234145109, 14.587093781354504], [121.0853581504601, 14.596021109784846], [121.08294945655366, 14.608610607901383], [121.07069510506479, 14.612271574884895], [121.06085075111193, 14.603344361547915]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-29T12:00:00',
#   'endTime': '2023-04-30T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-01T12:00:00',
#   'endTime': '2023-04-02T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-02T12:00:00',
#   'endTime': '2023-04-03T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-03T12:00:00',
#   'endTime': '2023-04-04T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-04T12:00:00',
#   'endTime': '2023-04-05T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-05T12:00:00',
#   'endTime': '2023-04-06T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-06T12:00:00',
#   'endTime': '2023-04-07T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-07T12:00:00',
#   'endTime': '2023-04-08T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-08T12:00:00',
#   'endTime': '2023-04-09T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-09T12:00:00',
#   'endTime': '2023-04-10T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-10T12:00:00',
#   'endTime': '2023-04-11T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-11T12:00:00',
#   'endTime': '2023-04-12T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-12T12:00:00',
#   'endTime': '2023-04-13T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-13T12:00:00',
#   'endTime': '2023-04-14T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-14T12:00:00',
#   'endTime': '2023-04-15T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-15T12:00:00',
#   'endTime': '2023-04-16T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-16T12:00:00',
#   'endTime': '2023-04-17T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-17T12:00:00',
#   'endTime': '2023-04-18T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-18T12:00:00',
#   'endTime': '2023-04-19T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-19T12:00:00',
#   'endTime': '2023-04-20T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-20T12:00:00',
#   'endTime': '2023-04-21T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-21T12:00:00',
#   'endTime': '2023-04-22T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-22T12:00:00',
#   'endTime': '2023-04-23T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-23T12:00:00',
#   'endTime': '2023-04-24T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-24T12:00:00',
#   'endTime': '2023-04-25T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-25T12:00:00',
#   'endTime': '2023-04-26T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-26T12:00:00',
#   'endTime': '2023-04-27T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-27T12:00:00',
#   'endTime': '2023-04-28T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-28T12:00:00',
#   'endTime': '2023-04-29T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.00140332766922, 14.4311818746626], [121.00381088389358, 14.418582884059878], [121.01605349835482, 14.414910046432972], [121.02588986118877, 14.42383751951722], [121.02348215151316, 14.436437723433103], [121.01123823227873, 14.44010924104793], [121.00140332766922, 14.4311818746626]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-29T12:00:00',
#   'endTime': '2023-04-30T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.08294945655366, 14.608610607901383], [121.0853581504601, 14.596021109784846], [121.09761398478429, 14.592357704167382], [121.1074624277528, 14.601285113370354], [121.10505358295818, 14.61387581281312], [121.09279644590634, 14.61753790182541], [121.08294945655366, 14.608610607901383]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-01T12:00:00',
#   'endTime': '2023-04-02T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.08294945655366, 14.608610607901383], [121.0853581504601, 14.596021109784846], [121.09761398478429, 14.592357704167382], [121.1074624277528, 14.601285113370354], [121.10505358295818, 14.61387581281312], [121.09279644590634, 14.61753790182541], [121.08294945655366, 14.608610607901383]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-02T12:00:00',
#   'endTime': '2023-04-03T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.08294945655366, 14.608610607901383], [121.0853581504601, 14.596021109784846], [121.09761398478429, 14.592357704167382], [121.1074624277528, 14.601285113370354], [121.10505358295818, 14.61387581281312], [121.09279644590634, 14.61753790182541], [121.08294945655366, 14.608610607901383]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-03T12:00:00',
#   'endTime': '2023-04-04T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.08294945655366, 14.608610607901383], [121.0853581504601, 14.596021109784846], [121.09761398478429, 14.592357704167382], [121.1074624277528, 14.601285113370354], [121.10505358295818, 14.61387581281312], [121.09279644590634, 14.61753790182541], [121.08294945655366, 14.608610607901383]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-04T12:00:00',
#   'endTime': '2023-04-05T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.08294945655366, 14.608610607901383], [121.0853581504601, 14.596021109784846], [121.09761398478429, 14.592357704167382], [121.1074624277528, 14.601285113370354], [121.10505358295818, 14.61387581281312], [121.09279644590634, 14.61753790182541], [121.08294945655366, 14.608610607901383]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-05T12:00:00',
#   'endTime': '2023-04-06T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.08294945655366, 14.608610607901383], [121.0853581504601, 14.596021109784846], [121.09761398478429, 14.592357704167382], [121.1074624277528, 14.601285113370354], [121.10505358295818, 14.61387581281312], [121.09279644590634, 14.61753790182541], [121.08294945655366, 14.608610607901383]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-06T12:00:00',
#   'endTime': '2023-04-07T12:00:00',
#   'units': 'metric'},
# ...
#   'endTime': '2023-04-13T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-13T12:00:00',
#   'endTime': '2023-04-14T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-14T12:00:00',
#   'endTime': '2023-04-15T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-15T12:00:00',
#   'endTime': '2023-04-16T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-16T12:00:00',
#   'endTime': '2023-04-17T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-17T12:00:00',
#   'endTime': '2023-04-18T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-18T12:00:00',
#   'endTime': '2023-04-19T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-19T12:00:00',
#   'endTime': '2023-04-20T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-20T12:00:00',
#   'endTime': '2023-04-21T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-21T12:00:00',
#   'endTime': '2023-04-22T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-22T12:00:00',
#   'endTime': '2023-04-23T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-23T12:00:00',
#   'endTime': '2023-04-24T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-24T12:00:00',
#   'endTime': '2023-04-25T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-25T12:00:00',
#   'endTime': '2023-04-26T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-26T12:00:00',
#   'endTime': '2023-04-27T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-27T12:00:00',
#   'endTime': '2023-04-28T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-28T12:00:00',
#   'endTime': '2023-04-29T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[120.97210754687683, 14.46371061950496], [120.97451504192543, 14.45111670819823], [120.9867546766171, 14.447448733556223], [120.99658812196587, 14.456375992377724], [120.99418047250266, 14.468971117316254], [120.98193953192938, 14.472637769897812], [120.97210754687683, 14.46371061950496]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-29T12:00:00',
#   'endTime': '2023-04-30T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-01T12:00:00',
#   'endTime': '2023-04-02T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-02T12:00:00',
#   'endTime': '2023-04-03T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-03T12:00:00',
#   'endTime': '2023-04-04T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-04T12:00:00',
#   'endTime': '2023-04-05T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-05T12:00:00',
#   'endTime': '2023-04-06T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-06T12:00:00',
#   'endTime': '2023-04-07T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-07T12:00:00',
#   'endTime': '2023-04-08T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-08T12:00:00',
#   'endTime': '2023-04-09T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-09T12:00:00',
#   'endTime': '2023-04-10T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-10T12:00:00',
#   'endTime': '2023-04-11T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-11T12:00:00',
#   'endTime': '2023-04-12T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-12T12:00:00',
#   'endTime': '2023-04-13T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-13T12:00:00',
#   'endTime': '2023-04-14T12:00:00',
#   'units': 'metric'},
#  {'location': '{"type": "Polygon", "coordinates": [[[121.01728607962383, 14.770516854263796], [121.0196949675531, 14.75794682631387], [121.03194580214416, 14.754302040066253], [121.04178905420821, 14.763228603715248], [121.03938001318535, 14.775799829972799], [121.02712787301553, 14.779443294373111], [121.01728607962383, 14.770516854263796]]]}',
#   'fields': ['temperatureMin', 'humidityMin'],
#   'timesteps': ['1d'],
#   'startTime': '2023-04-14T12:00:00',
#   'endTime': '2023-04-15T12:00:00',
#   'units': 'metric'},
#  ...]

# %% [markdown]
# Now, let's call the Tomorrow.io API!

# %%
async with TomorrowAPIClient(token=TOMORROW_API_KEY) as client:

    url = f"https://api.tomorrow.io/v4/historical"
    headers = {"Accept": "application/json", "Content-Type": "application/json"}

    futures = [client.post(url, json=payload, headers=headers) for payload in payloads]
    zamboanga = await asyncio.gather(*futures)

# %%
def get_values(x, field):
    if x is None:
        return None
    elif len(x[0]['intervals'])==0:
        return 0
    elif len(x[0]['intervals'])==1:
        #print(x[0]['intervals'])
        return x[0]['intervals'][0]['values'][field]
    else: 
        return np.mean([x[0]['intervals'][0]['values'][field], x[0]['intervals'][1]['values'][field]])

# %%
import numpy as np
def data_manipulation(manila, humidity, temperature):
    df = pd.json_normalize(manila).reset_index().merge(TESSELLATION.merge(pd.json_normalize(payloads), left_on = 'geojson', right_on ='location').reset_index())
    df = df[~df['data.timelines'].isna()]
    df[humidity] = df['data.timelines'].apply(lambda x: get_values(x, humidity))
    df[temperature] = df['data.timelines'].apply(lambda x: get_values(x, temperature))
    df = df[['geometry', 'startTime', 'endTime', humidity, temperature, 'hex_id', 'centre_geojson']]

    ftemp = temperature+'_F'

    df[ftemp] = df[temperature].apply(lambda x: weatherFunctions.convert_celcius_to_fahrenheit(x))
    
    # Make a change to use this convert function from the weatherFunctions module
    df['heat_index'] = df.apply(lambda x: weatherFunctions.calculate_heat_index(x[ftemp], x[humidity]), axis=1)
    df['heat_index_C'] = df['heat_index'].apply(lambda x: weatherFunctions.convert_fahrenheit_to_celcius(x))

    return df

# %%
zamboanga_heatindex_min= data_manipulation(zamboanga, 'humidityMin', 'temperatureMin')

# %%
zamboanga_heatindex_min.to_csv('../../data/tomorrow.io/zamboanga_april2023_min_heat_index.csv')

# %%
from utilities.weatherFunctions import *

# %%
df.to_csv('../../data/tomorrow.io/manila_20230420_20230427.csv')
